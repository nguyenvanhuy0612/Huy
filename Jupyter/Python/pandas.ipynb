# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np

# %%
# Read data from csv file
df = pd.read_csv("Student_Data.csv", delimiter='|')

# %%
df
# Out:
#    Student ID Preferred Name First Name Middle Name  Last Name Secondary ID  \
# 0        1001           Luke       Luke      Porter     Baxley        Q1001
# 1        1002         Marnie     Marnie       Gayle    Lemmons        Q1002
# 2        1003           Anne       Anne       Faith      Scott        Q1003
# 3        1004           Lucy       Lucy       Belle  Blakeslee        Q1004
# 4        1005        Chelsea    Chelsea    Savannah   Vlassman        Q1005
# 5        1006          Kelly      Kelly     Marilyn     Hudson        Q1006
# 6        1007           Todd       Todd  Washington  Robertson        Q1007
# 7        1008           Kirk       Kirk      Jeremy   Mitchell        Q1008
# 8        1009        Suzanne    Suzanne    Kathleen       Dunn        Q1009
#
#   Date of Birth        E-mail Address       Phone 1  \
# 0    01/02/1998  lpb@myUniversity.com  780-883-7269
# 1    11/07/1998  mgl@myUniversity.com  826-443-7227
# 2    02/02/1997  afs@myUniversity.com  759-315-2580
# 3    03/02/2000  lbb@myUniversity.com  956-277-5715
# 4    01/24/1997  scv@myUniversity.com  716-713-9011
# 5    01/25/1999  mkh@myUniversity.com  775-553-2558
# 6    01/21/1997  gtw@myUniversity.com  279-705-3782
# 7    01/20/1997  jkm@myUniversity.com  937-857-9883
# 8    11/20/1997  ksd@myUniversity.com  985-677-7127
#
#                                         Address 1       Phone 2  \
# 0        222 Lakeshore Drive<br>Abilene, TX 12345  404-925-4456
# 1  610 Spring Creek Drive<br>Waynesburg, PA 12345  819-724-9241
# 2        871 Lakeshore Drive<br>Abilene, TX 12345  114-876-8220
# 3        787 Ruth Street<br> Springfield TN 67890  827-308-2391
# 4        461 Lakeshore Drive<br>Abilene, TX 12345  431-594-8175
# 5        744 Ruth Street<br> Springfield TN 67890  646-431-2608
# 6        832 Lakeshore Drive<br>Abilene, TX 12345  786-200-2974
# 7        793 Ruth Street<br> Springfield TN 67890  961-413-7600
# 8        587 Lakeshore Drive<br>Abilene, TX 12345  535-429-1584
#
#                                  Address 2       Phone 3  \
# 0                                      NaN  325-204-5929
# 1                                      NaN  724-802-0816
# 2                                      NaN  325-674-2993
# 3                                      NaN  615-384-7495
# 4                                      NaN  325-669-5766
# 5  1006 College Drive<br>Abilene, TX 12345           NaN
# 6  1007 College Drive<br>Abilene, TX 12345           NaN
# 7  1008 College Drive<br>Abilene, TX 12345           NaN
# 8                                      NaN  325-370-2043
#
#                   Address 3               Address 4
# 0  Fischer West - Room W105  Campus Mail - Box 1001
# 1     Chase Hall - Room 129  Campus Mail - Box 1013
# 2  Fischer East - Room E165  Campus Mail - Box 1003
# 3  Fischer East - Room E219  Campus Mail - Box 1004
# 4     Chase Hall - Room 167  Campus Mail - Box 1005
# 5                       NaN  Campus Mail - Box 1006
# 6                       NaN  Campus Mail - Box 1007
# 7                       NaN  Campus Mail - Box 1008
# 8     Chase Hall - Room 255  Campus Mail - Box 1009

# %%
df.to_csv("filtered_students.csv")

# %%
# Dataframe information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student ID      9 non-null      int64
#  1   Preferred Name  9 non-null      object
#  2   First Name      9 non-null      object
#  3   Middle Name     9 non-null      object
#  4   Last Name       9 non-null      object
#  5   Secondary ID    9 non-null      object
#  6   Date of Birth   9 non-null      object
#  7   E-mail Address  9 non-null      object
#  8   Phone 1         9 non-null      object
#  9   Address 1       9 non-null      object
#  10  Phone 2         9 non-null      object
#  11  Address 2       3 non-null      object
#  12  Phone 3         6 non-null      object
#  13  Address 3       6 non-null      object
#  14  Address 4       9 non-null      object
# dtypes: int64(1), object(14)
# memory usage: 1.2+ KB

# %%
df[['First Name', 'Phone 1']]
# Out:
#   First Name       Phone 1
# 0       Luke  780-883-7269
# 1     Marnie  826-443-7227
# 2       Anne  759-315-2580
# 3       Lucy  956-277-5715
# 4    Chelsea  716-713-9011
# 5      Kelly  775-553-2558
# 6       Todd  279-705-3782
# 7       Kirk  937-857-9883
# 8    Suzanne  985-677-7127

# %%
# head
df.head(3)
# Out:
#    Student ID Preferred Name First Name Middle Name Last Name Secondary ID  \
# 0        1001           Luke       Luke      Porter    Baxley        Q1001
# 1        1002         Marnie     Marnie       Gayle   Lemmons        Q1002
# 2        1003           Anne       Anne       Faith     Scott        Q1003
#
#   Date of Birth        E-mail Address       Phone 1  \
# 0    01/02/1998  lpb@myUniversity.com  780-883-7269
# 1    11/07/1998  mgl@myUniversity.com  826-443-7227
# 2    02/02/1997  afs@myUniversity.com  759-315-2580
#
#                                         Address 1       Phone 2 Address 2  \
# 0        222 Lakeshore Drive<br>Abilene, TX 12345  404-925-4456       NaN
# 1  610 Spring Creek Drive<br>Waynesburg, PA 12345  819-724-9241       NaN
# 2        871 Lakeshore Drive<br>Abilene, TX 12345  114-876-8220       NaN
#
#         Phone 3                 Address 3               Address 4
# 0  325-204-5929  Fischer West - Room W105  Campus Mail - Box 1001
# 1  724-802-0816     Chase Hall - Room 129  Campus Mail - Box 1013
# 2  325-674-2993  Fischer East - Room E165  Campus Mail - Box 1003

# %%
# tail
df.tail(3)
# Out:
#    Student ID Preferred Name First Name Middle Name  Last Name Secondary ID  \
# 6        1007           Todd       Todd  Washington  Robertson        Q1007
# 7        1008           Kirk       Kirk      Jeremy   Mitchell        Q1008
# 8        1009        Suzanne    Suzanne    Kathleen       Dunn        Q1009
#
#   Date of Birth        E-mail Address       Phone 1  \
# 6    01/21/1997  gtw@myUniversity.com  279-705-3782
# 7    01/20/1997  jkm@myUniversity.com  937-857-9883
# 8    11/20/1997  ksd@myUniversity.com  985-677-7127
#
#                                   Address 1       Phone 2  \
# 6  832 Lakeshore Drive<br>Abilene, TX 12345  786-200-2974
# 7  793 Ruth Street<br> Springfield TN 67890  961-413-7600
# 8  587 Lakeshore Drive<br>Abilene, TX 12345  535-429-1584
#
#                                  Address 2       Phone 3  \
# 6  1007 College Drive<br>Abilene, TX 12345           NaN
# 7  1008 College Drive<br>Abilene, TX 12345           NaN
# 8                                      NaN  325-370-2043
#
#                Address 3               Address 4
# 6                    NaN  Campus Mail - Box 1007
# 7                    NaN  Campus Mail - Box 1008
# 8  Chase Hall - Room 255  Campus Mail - Box 1009

# %%
# index
df[2:7]
# Out:
#    Student ID Preferred Name First Name Middle Name  Last Name Secondary ID  \
# 2        1003           Anne       Anne       Faith      Scott        Q1003
# 3        1004           Lucy       Lucy       Belle  Blakeslee        Q1004
# 4        1005        Chelsea    Chelsea    Savannah   Vlassman        Q1005
# 5        1006          Kelly      Kelly     Marilyn     Hudson        Q1006
# 6        1007           Todd       Todd  Washington  Robertson        Q1007
#
#   Date of Birth        E-mail Address       Phone 1  \
# 2    02/02/1997  afs@myUniversity.com  759-315-2580
# 3    03/02/2000  lbb@myUniversity.com  956-277-5715
# 4    01/24/1997  scv@myUniversity.com  716-713-9011
# 5    01/25/1999  mkh@myUniversity.com  775-553-2558
# 6    01/21/1997  gtw@myUniversity.com  279-705-3782
#
#                                   Address 1       Phone 2  \
# 2  871 Lakeshore Drive<br>Abilene, TX 12345  114-876-8220
# 3  787 Ruth Street<br> Springfield TN 67890  827-308-2391
# 4  461 Lakeshore Drive<br>Abilene, TX 12345  431-594-8175
# 5  744 Ruth Street<br> Springfield TN 67890  646-431-2608
# 6  832 Lakeshore Drive<br>Abilene, TX 12345  786-200-2974
#
#                                  Address 2       Phone 3  \
# 2                                      NaN  325-674-2993
# 3                                      NaN  615-384-7495
# 4                                      NaN  325-669-5766
# 5  1006 College Drive<br>Abilene, TX 12345           NaN
# 6  1007 College Drive<br>Abilene, TX 12345           NaN
#
#                   Address 3               Address 4
# 2  Fischer East - Room E165  Campus Mail - Box 1003
# 3  Fischer East - Room E219  Campus Mail - Box 1004
# 4     Chase Hall - Room 167  Campus Mail - Box 1005
# 5                       NaN  Campus Mail - Box 1006
# 6                       NaN  Campus Mail - Box 1007

# %%
# condition
new_df = df[(df['First Name'] == 'Anne') & (df['Last Name'] == 'Scott')]

# %%
new_df
# Out:
#    Student ID Preferred Name First Name Middle Name Last Name Secondary ID  \
# 2        1003           Anne       Anne       Faith     Scott        Q1003
#
#   Date of Birth        E-mail Address       Phone 1  \
# 2    02/02/1997  afs@myUniversity.com  759-315-2580
#
#                                   Address 1       Phone 2 Address 2  \
# 2  871 Lakeshore Drive<br>Abilene, TX 12345  114-876-8220       NaN
#
#         Phone 3                 Address 3               Address 4
# 2  325-674-2993  Fischer East - Room E165  Campus Mail - Box 1003

# %%
# add a new column
df["New column"] = df['Preferred Name']

# %%
df
# Out:
#    Student ID Preferred Name First Name Middle Name  Last Name Secondary ID  \
# 0        1001           Luke       Luke      Porter     Baxley        Q1001
# 1        1002         Marnie     Marnie       Gayle    Lemmons        Q1002
# 2        1003           Anne       Anne       Faith      Scott        Q1003
# 3        1004           Lucy       Lucy       Belle  Blakeslee        Q1004
# 4        1005        Chelsea    Chelsea    Savannah   Vlassman        Q1005
# 5        1006          Kelly      Kelly     Marilyn     Hudson        Q1006
# 6        1007           Todd       Todd  Washington  Robertson        Q1007
# 7        1008           Kirk       Kirk      Jeremy   Mitchell        Q1008
# 8        1009        Suzanne    Suzanne    Kathleen       Dunn        Q1009
#
#   Date of Birth        E-mail Address       Phone 1  \
# 0    01/02/1998  lpb@myUniversity.com  780-883-7269
# 1    11/07/1998  mgl@myUniversity.com  826-443-7227
# 2    02/02/1997  afs@myUniversity.com  759-315-2580
# 3    03/02/2000  lbb@myUniversity.com  956-277-5715
# 4    01/24/1997  scv@myUniversity.com  716-713-9011
# 5    01/25/1999  mkh@myUniversity.com  775-553-2558
# 6    01/21/1997  gtw@myUniversity.com  279-705-3782
# 7    01/20/1997  jkm@myUniversity.com  937-857-9883
# 8    11/20/1997  ksd@myUniversity.com  985-677-7127
#
#                                         Address 1       Phone 2  \
# 0        222 Lakeshore Drive<br>Abilene, TX 12345  404-925-4456
# 1  610 Spring Creek Drive<br>Waynesburg, PA 12345  819-724-9241
# 2        871 Lakeshore Drive<br>Abilene, TX 12345  114-876-8220
# 3        787 Ruth Street<br> Springfield TN 67890  827-308-2391
# 4        461 Lakeshore Drive<br>Abilene, TX 12345  431-594-8175
# 5        744 Ruth Street<br> Springfield TN 67890  646-431-2608
# 6        832 Lakeshore Drive<br>Abilene, TX 12345  786-200-2974
# 7        793 Ruth Street<br> Springfield TN 67890  961-413-7600
# 8        587 Lakeshore Drive<br>Abilene, TX 12345  535-429-1584
#
#                                  Address 2       Phone 3  \
# 0                                      NaN  325-204-5929
# 1                                      NaN  724-802-0816
# 2                                      NaN  325-674-2993
# 3                                      NaN  615-384-7495
# 4                                      NaN  325-669-5766
# 5  1006 College Drive<br>Abilene, TX 12345           NaN
# 6  1007 College Drive<br>Abilene, TX 12345           NaN
# 7  1008 College Drive<br>Abilene, TX 12345           NaN
# 8                                      NaN  325-370-2043
#
#                   Address 3               Address 4 New column
# 0  Fischer West - Room W105  Campus Mail - Box 1001       Luke
# 1     Chase Hall - Room 129  Campus Mail - Box 1013     Marnie
# 2  Fischer East - Room E165  Campus Mail - Box 1003       Anne
# 3  Fischer East - Room E219  Campus Mail - Box 1004       Lucy
# 4     Chase Hall - Room 167  Campus Mail - Box 1005    Chelsea
# 5                       NaN  Campus Mail - Box 1006      Kelly
# 6                       NaN  Campus Mail - Box 1007       Todd
# 7                       NaN  Campus Mail - Box 1008       Kirk
# 8     Chase Hall - Room 255  Campus Mail - Box 1009    Suzanne

# %%
df['ID'] = np.where(df['Student ID'] % 2 == 0, 1, 0)

# %%
df.head(3)
# Out:
#    Student ID Preferred Name First Name Middle Name Last Name Secondary ID  \
# 0        1001           Luke       Luke      Porter    Baxley        Q1001
# 1        1002         Marnie     Marnie       Gayle   Lemmons        Q1002
# 2        1003           Anne       Anne       Faith     Scott        Q1003
#
#   Date of Birth        E-mail Address       Phone 1  \
# 0    01/02/1998  lpb@myUniversity.com  780-883-7269
# 1    11/07/1998  mgl@myUniversity.com  826-443-7227
# 2    02/02/1997  afs@myUniversity.com  759-315-2580
#
#                                         Address 1       Phone 2 Address 2  \
# 0        222 Lakeshore Drive<br>Abilene, TX 12345  404-925-4456       NaN
# 1  610 Spring Creek Drive<br>Waynesburg, PA 12345  819-724-9241       NaN
# 2        871 Lakeshore Drive<br>Abilene, TX 12345  114-876-8220       NaN
#
#         Phone 3                 Address 3               Address 4 New column  \
# 0  325-204-5929  Fischer West - Room W105  Campus Mail - Box 1001       Luke
# 1  724-802-0816     Chase Hall - Room 129  Campus Mail - Box 1013     Marnie
# 2  325-674-2993  Fischer East - Room E165  Campus Mail - Box 1003       Anne
#
#    ID
# 0   0
# 1   1
# 2   0
